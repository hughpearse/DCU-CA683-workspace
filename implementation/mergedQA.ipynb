# %%
import pandas as pd
import numpy as np
import sys

df = pd.read_csv('iris_with_missing_data.csv')
df['split'] = np.random.randn(df.shape[0], 1)

msk = np.random.rand(len(df)) <= 0.8

train = df[msk]
test = df[~msk]

print(train.head())
print(test.head())
print(train.shape,test.shape)

train.to_csv('trainingData.csv', index=False)
test.to_csv('testData.csv', index=False)

#set the sys argument for summary
sys.argv[0] = 'trainingData.csv'
sys.argv[1] = 'trainingData.csv'
sys.argv[2] = 'testData.csv'
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species     split
# 0           5.1          3.5           1.4          0.2  setosa  0.868199
# 1           4.9          3.0           1.4          0.2  setosa  0.800946
# 2           4.7          3.2           1.3          0.2  setosa -1.160231
# 3           4.6          3.1           1.5          0.2  setosa -0.575568
# 4           5.0          3.6           1.4          0.2  setosa -0.756723
#     Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species     split
# 7            5.0          3.4           1.5          0.2  setosa  0.375935
# 9            4.9          3.1           1.5          0.1  setosa  1.200786
# 12           4.8          3.0           1.4          0.1  setosa  2.135141
# 19           5.1          3.8           1.5          0.3  setosa  0.865178
# 21           NaN          NaN           1.5          0.4  setosa  0.124464
# (123, 6) (27, 6)

# %%
from merged import summary_evaluator_merged
# Out:
# ================================
# Summary statistics for: trainingData.csv
# Class distribution:
# virginica     11
# setosa         9
# versicolor     7
# Name: Species, dtype: int64
#
# setosa
# Min Sepal.Length: 4.4
# Max Sepal.Length: 5.3
# Mean Sepal.Length: 4.949999999999999
# Median Sepal.Length: 5.0
# Min Sepal.Width: 3.0
# Max Sepal.Width: 3.8
# Mean Sepal.Width: 3.4375
# Median Sepal.Width: 3.45
# Min Petal.Length: 1.3
# Max Petal.Length: 1.6
# Mean Petal.Length: 1.488888888888889
# Median Petal.Length: 1.5
# Min Petal.Width: 0.1
# Max Petal.Width: 0.6
# Mean Petal.Width: 0.2555555555555556
# Median Petal.Width: 0.2
#
# versicolor
# Min Sepal.Length: 5.4
# Max Sepal.Length: 6.3
# Mean Sepal.Length: 5.857142857142857
# Median Sepal.Length: 5.8
# Min Sepal.Width: 2.2
# Max Sepal.Width: 3.0
# Mean Sepal.Width: 2.6
# Median Sepal.Width: 2.7
# Min Petal.Length: 3.9
# Max Petal.Length: 4.5
# Mean Petal.Length: 4.271428571428571
# Median Petal.Length: 4.4
# Min Petal.Width: 1.0
# Max Petal.Width: 1.5
# Mean Petal.Width: 1.3
# Median Petal.Width: 1.3
#
# virginica
# Min Sepal.Length: 6.0
# Max Sepal.Length: 7.9
# Mean Sepal.Length: 6.736363636363635
# Median Sepal.Length: 6.5
# Min Sepal.Width: 2.2
# Max Sepal.Width: 3.8
# Mean Sepal.Width: 3.0727272727272723
# Median Sepal.Width: 3.1
# Min Petal.Length: 5.0
# Max Petal.Length: 6.7
# Mean Petal.Length: 5.618181818181818
# Median Petal.Length: 5.6
# Min Petal.Width: 1.5
# Max Petal.Width: 2.4
# Mean Petal.Width: 2.0181818181818176
# Median Petal.Width: 2.0
#
# ================================
# Summary statistics for: merged
# Class distribution:
# setosa        50
# virginica     50
# versicolor    50
# Name: Species, dtype: int64
#
# setosa
# Min Sepal.Length: 4.3
# Max Sepal.Length: 5.8
# Mean Sepal.Length: 5.000000000000001
# Median Sepal.Length: 5.0
# Min Sepal.Width: 2.3
# Max Sepal.Width: 4.4
# Mean Sepal.Width: 3.4191489361702123
# Median Sepal.Width: 3.4
# Min Petal.Length: 1.0
# Max Petal.Length: 1.9
# Mean Petal.Length: 1.46938775510204
# Median Petal.Length: 1.5
# Min Petal.Width: 0.1
# Max Petal.Width: 0.6
# Mean Petal.Width: 0.24599999999999997
# Median Petal.Width: 0.2
#
# versicolor
# Min Sepal.Length: 4.9
# Max Sepal.Length: 7.0
# Mean Sepal.Length: 5.935999999999998
# Median Sepal.Length: 5.9
# Min Sepal.Width: 2.0
# Max Sepal.Width: 3.4
# Mean Sepal.Width: 2.775510204081633
# Median Sepal.Width: 2.8
# Min Petal.Length: 3.0
# Max Petal.Length: 5.1
# Mean Petal.Length: 4.26
# Median Petal.Length: 4.35
# Min Petal.Width: 1.0
# Max Petal.Width: 1.8
# Mean Petal.Width: 1.3259999999999998
# Median Petal.Width: 1.3
#
# virginica
# Min Sepal.Length: 4.9
# Max Sepal.Length: 7.9
# Mean Sepal.Length: 6.564583333333332
# Median Sepal.Length: 6.45
# Min Sepal.Width: 2.2
# Max Sepal.Width: 3.8
# Mean Sepal.Width: 2.973469387755102
# Median Sepal.Width: 3.0
# Min Petal.Length: 4.5
# Max Petal.Length: 6.9
# Mean Petal.Length: 5.561224489795919
# Median Petal.Length: 5.6
# Min Petal.Width: 1.4
# Max Petal.Width: 2.5
# Mean Petal.Width: 2.026
# Median Petal.Width: 2.0
#
# Feature Importance (Chi^2): [ 6.05646755  2.00080724 77.06519977 47.24269894]
# Features Selected: [False False  True  True]
# Selecting: ['Petal.Length' 'Petal.Width']
#
# Evaluating classifiers:
# name,accuracy,std_dev
# LR,0.880000,0.097980
# LDA,0.958889,0.050442
# KNN,0.958889,0.050442
# CART,0.958889,0.050442
# NB,0.948889,0.051208
# SVM,0.947778,0.052364
# MLP,0.948889,0.051208
# RFC,0.958889,0.050442
