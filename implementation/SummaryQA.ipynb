# %%
import pandas as pd
import numpy as np
import sys

df = pd.read_csv('iris.csv')
df['split'] = np.random.randn(df.shape[0], 1)

msk = np.random.rand(len(df)) <= 0.8

train = df[msk]
test = df[~msk]

#print(train.head())
#print(test.head())
#print(train.shape,test.shape)

train.to_csv('trainingData.csv', index=False)
test.to_csv('testData.csv', index=False)

#set the sys argument for summary
sys.argv[0] = 'trainingData.csv'
sys.argv[1] = 'trainingData.csv'
sys.argv[2] = 'testData.csv'

# %%
import summary
# Out:
# ================================
# Summary statistics for: trainingData.csv
# Class distribution:
# Iris-virginica     47
# Iris-versicolor    41
# Iris-setosa        38
# Name: class, dtype: int64
#
# Iris-setosa
# Min sepal length: 4.3
# Max sepal length: 5.8
# Mean sepal length: 4.981578947368422
# Median sepal length: 5.0
# Min sepal width: 2.3
# Max sepal width: 4.4
# Mean sepal width: 3.3736842105263163
# Median sepal width: 3.4
# Min petal length: 1.0
# Max petal length: 1.7
# Mean petal length: 1.439473684210526
# Median petal length: 1.5
# Min petal width: 0.1
# Max petal width: 0.6
# Mean petal width: 0.2421052631578947
# Median petal width: 0.2
#
# Iris-versicolor
# Min sepal length: 4.9
# Max sepal length: 7.0
# Mean sepal length: 5.899999999999999
# Median sepal length: 5.8
# Min sepal width: 2.0
# Max sepal width: 3.3
# Mean sepal width: 2.765853658536585
# Median sepal width: 2.8
# Min petal length: 3.3
# Max petal length: 4.9
# Mean petal length: 4.224390243902439
# Median petal length: 4.3
# Min petal width: 1.0
# Max petal width: 1.8
# Mean petal width: 1.3073170731707313
# Median petal width: 1.3
#
# Iris-virginica
# Min sepal length: 4.9
# Max sepal length: 7.9
# Mean sepal length: 6.6
# Median sepal length: 6.5
# Min sepal width: 2.2
# Max sepal width: 3.8
# Mean sepal width: 2.9829787234042553
# Median sepal width: 3.0
# Min petal length: 4.5
# Max petal length: 6.9
# Mean petal length: 5.5765957446808505
# Median petal length: 5.6
# Min petal width: 1.5
# Max petal width: 2.5
# Mean petal width: 2.0382978723404253
# Median petal width: 2.0
#
# ================================
# Summary statistics for: testData.csv
# Class distribution:
# Iris-setosa        12
# Iris-versicolor     9
# Iris-virginica      3
# Name: class, dtype: int64
#
# Iris-setosa
# Min sepal length: 4.8
# Max sepal length: 5.5
# Mean sepal length: 5.083333333333334
# Median sepal length: 5.1
# Min sepal width: 3.0
# Max sepal width: 4.2
# Mean sepal width: 3.558333333333333
# Median sepal width: 3.45
# Min petal length: 1.3
# Max petal length: 1.9
# Mean petal length: 1.5416666666666667
# Median petal length: 1.5
# Min petal width: 0.1
# Max petal width: 0.5
# Mean petal width: 0.25000000000000006
# Median petal width: 0.2
#
# Iris-versicolor
# Min sepal length: 5.1
# Max sepal length: 6.9
# Mean sepal length: 6.1000000000000005
# Median sepal length: 6.0
# Min sepal width: 2.2
# Max sepal width: 3.4
# Mean sepal width: 2.788888888888889
# Median sepal width: 2.8
# Min petal length: 3.0
# Max petal length: 5.1
# Mean petal length: 4.4222222222222225
# Median petal length: 4.5
# Min petal width: 1.1
# Max petal width: 1.7
# Mean petal width: 1.411111111111111
# Median petal width: 1.5
#
# Iris-virginica
# Min sepal length: 6.1
# Max sepal length: 6.9
# Mean sepal length: 6.400000000000001
# Median sepal length: 6.2
# Min sepal width: 2.6
# Max sepal width: 3.1
# Mean sepal width: 2.8333333333333335
# Median sepal width: 2.8
# Min petal length: 4.8
# Max petal length: 5.6
# Mean petal length: 5.166666666666666
# Median petal length: 5.1
# Min petal width: 1.4
# Max petal width: 2.3
# Mean petal width: 1.8333333333333333
# Median petal width: 1.8
#
# ================================
# Summary statistics for: merged
# Class distribution:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        50
# Name: class, dtype: int64
#
# Iris-setosa
# Min sepal length: 4.3
# Max sepal length: 5.8
# Mean sepal length: 5.006
# Median sepal length: 5.0
# Min sepal width: 2.3
# Max sepal width: 4.4
# Mean sepal width: 3.4180000000000006
# Median sepal width: 3.4
# Min petal length: 1.0
# Max petal length: 1.9
# Mean petal length: 1.4639999999999997
# Median petal length: 1.5
# Min petal width: 0.1
# Max petal width: 0.6
# Mean petal width: 0.2439999999999999
# Median petal width: 0.2
#
# Iris-versicolor
# Min sepal length: 4.9
# Max sepal length: 7.0
# Mean sepal length: 5.935999999999999
# Median sepal length: 5.9
# Min sepal width: 2.0
# Max sepal width: 3.4
# Mean sepal width: 2.77
# Median sepal width: 2.8
# Min petal length: 3.0
# Max petal length: 5.1
# Mean petal length: 4.260000000000001
# Median petal length: 4.35
# Min petal width: 1.0
# Max petal width: 1.8
# Mean petal width: 1.3259999999999996
# Median petal width: 1.3
#
# Iris-virginica
# Min sepal length: 4.9
# Max sepal length: 7.9
# Mean sepal length: 6.587999999999999
# Median sepal length: 6.5
# Min sepal width: 2.2
# Max sepal width: 3.8
# Mean sepal width: 2.9739999999999998
# Median sepal width: 3.0
# Min petal length: 4.5
# Max petal length: 6.9
# Mean petal length: 5.5520000000000005
# Median petal length: 5.55
# Min petal width: 1.4
# Max petal width: 2.5
# Mean petal width: 2.026
# Median petal width: 2.0

# %%
import evaluator
# Out:
# Feature Importance (Chi^2): [ 7.93727129  2.5788514  89.39450141 51.18006382]
# Features Selected: [False False  True  True]
# Selecting: ['petal length' 'petal width']
#
# Evaluating classifiers:
# name,accuracy,std_dev
# LR,0.856364,0.090069
# LDA,0.961818,0.062032
# KNN,0.970909,0.044499
# CART,0.960909,0.047941
# NB,0.970909,0.044499
# SVM,0.951818,0.048285
# MLP,0.970909,0.044499
# RFC,0.960909,0.047941
# GPC,0.970909,0.044499
# ABC,0.960909,0.047941
# QDA,0.990000,0.030000
# SDG,0.719091,0.193337
# GBC,0.960909,0.047941
# NSVC,0.960909,0.047941
#
# Selected classifier: QDA
#
# QDA classifier validation test results:
# petal length,petal width,real-class,predicted-class
# [[5.0 1.7 'Iris-versicolor' 'Iris-versicolor']
#  [4.8 1.8 'Iris-versicolor' 'Iris-virginica']
#  [1.6 0.6 'Iris-setosa' 'Iris-setosa']
#  [5.3 1.9 'Iris-virginica' 'Iris-virginica']
#  [6.9 2.3 'Iris-virginica' 'Iris-virginica']
#  [6.1 2.3 'Iris-virginica' 'Iris-virginica']
#  [4.9 1.5 'Iris-versicolor' 'Iris-versicolor']
#  [5.1 1.9 'Iris-virginica' 'Iris-virginica']
#  [4.9 2.0 'Iris-virginica' 'Iris-virginica']
#  [1.6 0.2 'Iris-setosa' 'Iris-setosa']
#  [4.8 1.4 'Iris-versicolor' 'Iris-versicolor']
#  [6.1 2.5 'Iris-virginica' 'Iris-virginica']
#  [4.6 1.4 'Iris-versicolor' 'Iris-versicolor']
#  [5.4 2.1 'Iris-virginica' 'Iris-virginica']
#  [5.5 2.1 'Iris-virginica' 'Iris-virginica']
#  [5.1 1.8 'Iris-virginica' 'Iris-virginica']
#  [5.6 2.1 'Iris-virginica' 'Iris-virginica']
#  [5.1 2.0 'Iris-virginica' 'Iris-virginica']
#  [4.7 1.2 'Iris-versicolor' 'Iris-versicolor']
#  [5.6 2.4 'Iris-virginica' 'Iris-virginica']
#  [1.5 0.2 'Iris-setosa' 'Iris-setosa']
#  [5.1 1.5 'Iris-virginica' 'Iris-versicolor']
#  [3.3 1.0 'Iris-versicolor' 'Iris-versicolor']
#  [1.5 0.4 'Iris-setosa' 'Iris-setosa']
#  [4.0 1.3 'Iris-versicolor' 'Iris-versicolor']
#  [5.0 2.0 'Iris-virginica' 'Iris-virginica']
#  [1.5 0.1 'Iris-setosa' 'Iris-setosa']]
# Accuracy: 0.9259259259259259
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         5
# Iris-versicolor       0.88      0.88      0.88         8
#  Iris-virginica       0.93      0.93      0.93        14
#
#     avg / total       0.93      0.93      0.93        27
